# %% [markdown]
# <a href="https://colab.research.google.com/github/soumyaattili52/Lab_FMML/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-31 11:13:33--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   169MB/s    in 0.4s
#
# 2024-03-31 11:13:34 (169 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 1878   1802.04223v1  Structured prediction requires searching over ...  stat
# 11711  1610.04336v4  Strict Minimum Message Length (SMML) is a stat...  stat
# 1250   1701.04949v1  This paper presents the development of several...    cs
# 35160  cs/0003018v1  This article describes the first implementatio...    cs
# 22362  1603.06340v1  If a document is about travel, we may expect t...  stat
# ...             ...                                                ...   ...
# 38072   1204.3498v2  This paper is focused on the computational ana...    cs
# 5267    1208.3728v2  We present methods for online linear optimizat...  stat
# 35551   0902.3614v1  We study the combination of the following alre...    cs
# 2209   1706.10234v1  We consider the problem of learning the functi...  stat
# 9707   1709.07267v1  In recent years, the number of papers on Alzhe...  stat
#
#                                                    title  year  \
# 1878   SparseMAP: Differentiable Sparse Structured In...  2018
# 11711             MML is not consistent for Neyman-Scott  2016
# 1250   A Deep Convolutional Auto-Encoder with Pooling...  2017
# 35160                               Description of GADEL  2000
# 22362               Data Augmentation via Levy Processes  2016
# ...                                                  ...   ...
# 38072   A Computational Analysis of Collective Discourse  2012
# 5267          Online Learning with Predictable Sequences  2012
# 35551  Syntactic Confluence Criteria for Positive/Neg...  2009
# 2209   Probabilistic Active Learning of Functions in ...  2017
# 9707   Yet Another ADNI Machine Learning Paper? Pavin...  2017
#
#                                                 keywords
# 1878   [structured, prediction, searching, combinator...
# 11711  [statistical, inference, providing, estimation...
# 1250   [development, convolutional, framework, experi...
# 35160  [describes, implementation, algorithm, extensi...
# 22362  [introduce, framework, incorporating, invarian...
# ...                                                  ...
# 38072  [computational, collective, discourse, collect...
# 5267   [optimization, advantage, sequences, specifica...
# 35551  [combination, following, confluence, unconditi...
# 2209   [functions, computing, structural, underlying,...
# 9707   [alzheimers, classification, increased, dramat...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 1878     [structured, prediction, searching, combinator...
# 11711    [statistical, inference, providing, estimation...
# 1250     [development, convolutional, framework, experi...
# 35160    [describes, implementation, algorithm, extensi...
# 22362    [introduce, framework, incorporating, invarian...
#                                ...
# 19124    [describes, framework, functions, sentation, n...
# 3796     [techniques, increasingly, prediction, functio...
# 2056     [preference, elicitation, configuration, appro...
# 6056     [variational, autoencoders, approaches, unsupe...
# 13373    [comparison, approaches, interfacing, approach...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8823 words.
# Out of those 4579 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="f98580cf-ecb2-43cc-ac27-96b911f53aa7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f98580cf-ecb2-43cc-ac27-96b911f53aa7")) {                    Plotly.newPlot(                        "f98580cf-ecb2-43cc-ac27-96b911f53aa7",                        [{"x":["attractive","ambiguities","introduce","inference","structured","regardless","combinatorial","prediction","including","corresponding","interpretability","structure","intractable","functions","automatically","searching","differentiable","probability","assignment","importantly","applicable","dependency","competitive","efficient","structures","experiments","backpropagation","estimations","providing","invariably","consistency","consistent","construction","approximations","dimensional","appearing","counterexample","literature","estimation","investigate","regarding","statistical","practical","experimental","developed","perceptron","deconvolution","unsupervised","classifier","researchers","analogous","presented","unpooling","discusses","clustering","dimensionality","convolutional","development","framework","supervised","evaluation","reduction","variables","classification","architectures","description","algorithm","algorithms","extensions","propositional","instances","implementation","principles","evolutionary","describes","successful","additional","preserves","invariances","equivalent","generalizations","discriminative","generative","desirable","incorporating","augmentation","processes","properties","admitting","conversations","computational","techniques","treatments","processing","knowledge","application","conversation","discourse","quantitative","actionable","correlated","strategies","psycholinguistics","associated","effective","frequency","linguistic","comparisons","extending","extraction","centerline","operators","deterministic","annotator","regression","inception","detection","biomedical","segmentation","embedding","efficiency","continuous","principle","algebraic","relations","especially","transforming","numerical","characterize","baselines","substantial","geometric","improvements","representation","extensive","dictionary","pronunciation","acceptable","affecting","pronunciations","generation","variations","providers","challenging","technique","generalizes","dictionaries","recognition","canonical","directory","discriminant","decomposed","occurring","semantics","different","temporally","represented","specifically","expression","naturally","alignment","spatially","evaluated","databases","outperforms","statistically","constructed","intervals","processed","universal","instantiated","characterized","compression","improvement","analyzing","objective","measurement","simulation","estimating","prevalent","artifacts","applications","resonance","connectome","functional","explosion","methodology","populations","significant","challenges","measuring","promising","potential","understanding","suggested","exploring","connectivity","accurately","interface","accompanied"],"y":[22,6,317,198,101,11,42,215,233,125,18,343,20,209,175,26,27,171,23,37,50,36,134,415,120,562,13,13,94,1,53,90,72,27,194,10,0,115,215,153,45,136,122,372,199,21,9,161,140,68,9,159,2,25,144,59,391,136,537,201,223,118,102,510,115,79,830,572,61,22,93,139,33,67,93,67,121,13,0,52,9,113,108,28,58,31,93,205,1,10,276,367,6,283,335,227,11,21,68,7,39,97,2,99,236,59,57,32,33,130,1,60,39,5,121,13,364,19,187,120,173,96,58,20,107,120,10,74,63,60,44,78,122,336,174,43,4,11,4,2,146,73,5,268,251,28,18,373,22,3,13,9,20,102,731,16,89,165,41,64,66,23,153,59,250,14,58,11,32,30,6,38,40,167,63,155,44,76,53,9,18,394,18,0,33,14,71,16,226,126,28,136,168,154,30,42,28,52,34,12],"type":"bar"},{"x":["attractive","ambiguities","introduce","inference"," ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4579,), (4579, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.815

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Analysis</span> <span style=''>of</span> <span style=''>Solution</span> <span style=''>Quality</span> <span style=''>of</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>Multiobjective</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Optimization</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.8611111111111112);'>Evolutionary</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Algorithm</span> <span style=''>for</span> <span style=''>Knapsack</span> <span style=''>Problem</span> <br/><br/><span style=''>Multi</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>objective</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimisation</span> <span style=''>is</span> <span style=''>regarded</span> <span style=''>as</span> <span style=''>one</span> <span style=''>of</span> <span style=''>the</span> <span style=''>most</span> <span style='background-color:rgba(0, 255, 0, 0.4240837696335079);'>promising</span> <span style=''>ways</span> <span style=''>for</span> <span style=''>dealing</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>constrained</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimisation</span> <span style=''>problems</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.8611111111111112);'>evolutionary</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimisation</span> <span style=''>This</span> <span style=''>paper</span> <span style=''>presents</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>theoretical</span> <span style='background-color:rgba(0, 255, 0, 0.3469387755102041);'>investigation</span> <span style=''>of</span> <span style=''>a</span> <span style=''>multi</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>objective</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimisation</span> <span style='background-color:rgba(0, 255, 0, 0.8611111111111112);'>evolutionary</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style=''>solving</span> <span style=''>the</span> <span style=''>0</span> <span style=''>1</span> <span style=''>knapsack</span> <span style=''>problem</span> <span style=''>Two</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>initialisation</span> <span style=''>methods</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>considered</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>local</span> <span style=''>search</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>initialisation</span> <span style=''>and</span> <span style=''>greedy</span> <span style=''>search</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>initialisation</span> <span style=''>Then</span> <span style=''>the</span> <span style=''>solution</span> <span style=''>quality</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>is</span> <span style=''>analysed</span> <span style=''>in</span> <span style=''>terms</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3090909090909092);'>approximation</span> <span style=''>ratio</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Edge</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>exchangeable</span> <span style=''>graphs</span> <span style=''>and</span> <span style=''>sparsity</span> <span style=''>(NIPS</span> <span style=''>2016)</span> <br/><br/><span style=''>Many</span> <span style=''>popular</span> <span style=''>network</span> <span style=''>models</span> <span style=''>rely</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>assumption</span> <span style=''>of</span> <span style=''>(vertex)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>exchangeability</span> <span style=''>in</span> <span style=''>which</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>of</span> <span style=''>the</span> <span style=''>graph</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>invariant</span> <span style=''>to</span> <span style=''>relabelings</span> <span style=''>of</span> <span style=''>the</span> <span style=''>vertices</span> <span style=''>However</span> <span style=''>the</span> <span style=''>Aldous</span> <span style=''>Hoover</span> <span style=''>theorem</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>guarantees</span> <span style=''>that</span> <span style=''>these</span> <span style=''>graphs</span> <span style=''>are</span> <span style=''>dense</span> <span style=''>or</span> <span style=''>empty</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probability</span> <span style=''>one</span> <span style=''>whereas</span> <span style=''>many</span> <span style=''>real</span> <span style=''>world</span> <span style=''>graphs</span> <span style=''>are</span> <span style=''>sparse</span> <span style=''>We</span> <span style=''>present</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>alternative</span> <span style=''>notion</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>exchangeability</span> <span style=''>for</span> <span style=''>random</span> <span style=''>graphs</span> <span style=''>which</span> <span style=''>we</span> <span style=''>call</span> <span style=''>edge</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>exchangeability</span> <span style=''>in</span> <span style=''>which</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>of</span> <span style=''>a</span> <span style=''>graph</span> <span style=''>sequence</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>invariant</span> <span style=''>to</span> <span style=''>the</span> <span style=''>order</span> <span style=''>of</span> <span style=''>the</span> <span style=''>edges</span> <span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>demonstrate</span> <span style=''>that</span> <span style=''>edge</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>exchangeable</span> <span style=''>models</span> <span style=''>unlike</span> <span style=''>models</span> <span style=''>that</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>traditionally</span> <span style=''>vertex</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>exchangeable</span> <span style=''>can</span> <span style=''>exhibit</span> <span style=''>sparsity</span> <span style=''>To</span> <span style=''>do</span> <span style=''>so</span> <span style=''>we</span> <span style=''>outline</span> <span style=''>a</span> <span style=''>general</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>for</span> <span style=''>graph</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generative</span> <span style=''>models</span> <span style=''>by</span> <span style=''>contrast</span> <spa ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>When</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.5000000000000001);'>Overcomplete</span> <span style=''>Topic</span> <span style=''>Models</span> <span style='background-color:rgba(255, 0, 0, 0.8000000000000002);'>Identifiable</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Uniqueness</span> <span style=''>of</span> <span style=''>Tensor</span> <span style=''>Tucker</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333337);'>Decompositions</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Structured</span> <span style=''>Sparsity</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.5000000000000001);'>Overcomplete</span> <span style=''>latent</span> <span style='background-color:rgba(0, 255, 0, 0.45086705202312133);'>representations</span> <span style=''>have</span> <span style=''>been</span> <span style=''>very</span> <span style=''>popular</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>unsupervised</span> <span style=''>feature</span> <span style=''>learning</span> <span style=''>in</span> <span style=''>recent</span> <span style=''>years</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>specify</span> <span style=''>which</span> <span style='background-color:rgba(0, 255, 0, 0.5000000000000001);'>overcomplete</span> <span style=''>models</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.37142857142857144);'>identified</span> <span style=''>given</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observable</span> <span style=''>moments</span> <span style=''>of</span> <span style=''>a</span> <span style=''>certain</span> <span style=''>order</span> <span style=''>We</span> <span style=''>consider</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilistic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>admixture</span> <span style=''>or</span> <span style=''>topic</span> <span style=''>models</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.5000000000000001);'>overcomplete</span> <span style=''>regime</span> <span style=''>where</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>latent</span> <span style=''>topics</span> <span style=''>can</span> <span style=''>greatly</span> <span style=''>exceed</span> <span style=''>the</span> <span style=''>size</span> <span style=''>of</span> <span style=''>the</span> <span style=''>observed</span> <span style=''>word</span> <span style='background-color:rgba(0, 255, 0, 0.6363636363636362);'>vocabulary</span> <span style=''>While</span> <span style=''>general</span> <span style='background-color:rgba(0, 255, 0, 0.5000000000000001);'>overcomplete</span> <span style=''>topic</span> <span style=''>models</span> <span style=''>are</span> <span style=''>not</span> <span style='background-color:rgba(255, 0, 0, 0.8000000000000002);'>identifiable</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>establish</span> <span style=''>generic</span> <span style='background-color:rgba(255, 0, 0, 0.7142857142857142);'>identifiability</span> <span style=''>under</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constraint</span> <span style=''>referred</span> <span style=''>to</span> <span style=''>as</span> <span style=''>topic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>persistence</span> <span style=''>Our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sufficient</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditions</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.7142857142857142);'>identifiability</span> <span style=''>in ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Retrieval</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Experiments</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Efficient</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Estimation</span> <span style=''>of</span> <span style=''>Marginal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Likelihood</span> <br/><br/><span style=''>We</span> <span style=''>study</span> <span style=''>the</span> <span style=''>task</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>retrieving</span> <span style=''>relevant</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>experiments</span> <span style=''>given</span> <span style=''>a</span> <span style=''>query</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>experiment</span> <span style=''>By</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>experiment</span> <span style=''>we</span> <span style=''>mean</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>collection</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>measurements</span> <span style=''>from</span> <span style=''>a</span> <span style=''>set</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>covariates</span> <span style=''>and</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>associated</span> <span style=''>outcomes</span> <span style=''>While</span> <span style=''>similar</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>experiments</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>retrieved</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>comparing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>available</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>annotations</span> <span style=''>this</span> <span style=''>approach</span> <span style=''>ignores</span> <span style=''>the</span> <span style=''>valuable</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>available</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>measurements</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>themselves</span> <span style=''>To</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>incorporate</span> <span style=''>this</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>retrieval</span> <span style=''>task</span> <span style=''>we</span> <span style=''>suggest</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>employing</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>retrieval</span> <span style=''>metric</span> <span style=''>that</span> <span style=''>utilizes</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilistic</span> <span style=''>models</span> <span style=''>learned</span> <span style=''>from</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>measurements</span> <span style=''>We</span> <span style=''>argue</span> <span style=''>that</span> <span style=''>such</span> <span style=''>a</span> <span style=''>metric</span> <span style=''>is</span> <span style=''>a</span> <span style=''>sensible</span> <span style=''>measure</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>similarity</span> <span style=''>between</span> <span style=''>two</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>experiments</span> <span style=''>since</span> <span ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	knowledge (0.11989978525411596)
# 	segmentation (0.06692913385826772)
# 	processing (0.10128847530422333)
# 	experimental (0.13314244810307801)
# 	architecture (0.09520400858983537)
# 	information (0.256621331424481)
# 	different (0.2616320687186829)
# 	detection (0.13027916964924838)
# 	recognition (0.13350035790980672)
# 	convolutional (0.13994273443092342)
#
# Some Statistics words are:
# 	theoretical (0.15004985044865404)
# 	algorithm (0.3913260219341974)
# 	stochastic (0.13958125623130607)
# 	statistical (0.15004985044865404)
# 	variables (0.14057826520438685)
# 	distribution (0.17996011964107678)
# 	estimation (0.18195413758723827)
# 	inference (0.1864406779661017)
# 	dimensional (0.1959122632103689)
# 	regression (0.17746759720837488)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="4256a13c-3d3d-461f-84f8-e7d73aee1146" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4256a13c-3d3d-461f-84f8-e7d73aee1146")) {                    Plotly.newPlot(                        "4256a13c-3d3d-461f-84f8-e7d73aee1146",                        [{"x":["attractive","ambiguities","introduce","inference","structured","regardless","combinatorial","prediction","including","corresponding","interpretability","structure","intractable","functions","automatically","searching","differentiable","probability","assignment","importantly","applicable","dependency","competitive","efficient","structures","experiments","backpropagation","estimations","providing","invariably","consistency","consistent","construction","approximations","dimensional","appearing","counterexample","literature","estimation","investigate","regarding","statistical","practical","experimental","developed","perceptron","deconvolution","unsupervised","classifier","researchers","analogous","presented","unpooling","discusses","clustering","dimensionality","convolutional","development","framework","supervised","evaluation","reduction","variables","classification","architectures","description","algorithm","algorithms","extensions","propositional","instances","implementation","principles","evolutionary","describes","successful","additional","preserves","invariances","equivalent","generalizations","discriminative","generative","desirable","incorporating","augmentation","processes","properties","admitting","conversations","computational","techniques","treatments","processing","knowledge","application","conversation","discourse","quantitative","actionable","correlated","strategies","psycholinguistics","associated","effective","frequency","linguistic","comparisons","extending","extraction","centerline","operators","deterministic","annotator","regression","inception","detection","biomedical","segmentation","embedding","efficiency","continuous","principle","algebraic","relations","especially","transforming","numerical","characterize","baselines","substantial","geometric","improvements","representation","extensive","dictionary","pronunciation","acceptable","affecting","pronunciations","generation","variations","providers","challenging","technique","generalizes","dictionaries","recognition","canonical","directory","discriminant","decomposed","occurring","semantics","different","temporally","represented","specifically","expression","naturally","alignment","spatially","evaluated","databases","outperforms","statistically","constructed","intervals","processed","universal","instantiated","characterized","compression","improvement","analyzing","objective","measurement","simulation","estimating","prevalent","artifacts","applications","resonance","connectome","functional","explosion","methodology","populations","significant","challenges","measuring","promising","potential","understanding","suggested","exploring","connectivity","accurately","interface","accompanied","interfaces","environment","implement","performance","standalone","preprocessing","important","redundancy","reinforcement","photographs","conventional","automatic","operations","decisions","formulated","independent","expertise","preferences","understandable","significantly","difficult","resolution","generates","parameters","capability","memberships","membership","segmentations","segmenting","transition","allocation","parameter","dirichlet","separable","demonstrate","satellites","validates","perceptually","distinguish","superiority","particular","virtually","regularization","computing","identification","generalize","considered","technology","increasingly","inapplicable","stochastic","implemented","optimized","malicious","co ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	counterexample
# 	invariances
# 	connectome
# 	jackknife
# 	overfitted
# 	submodels
# 	parametrically
# 	contextually
# 	sociology
# 	procrustes
# 	hoeffding
# 	intercept
# 	exponentiated
# 	synchronization
# 	functionals
# 	ellipsoids
# 	subsampled
# 	encounters
# 	physiologic
# 	assortment
# Some words which never appear in Statistics papers:
# 	propositional
# 	conversations
# 	conversation
# 	discourse
# 	psycholinguistics
# 	pronunciation
# 	pronunciations
# 	satellites
# 	perceptually
# 	reflected
# 	narratives
# 	argumentation
# 	elaboration
# 	interrelationships
# 	fortunately
# 	organizational
# 	derivational
# 	annotating
# 	associating
# 	assimilate

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.075125311356438e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7775
